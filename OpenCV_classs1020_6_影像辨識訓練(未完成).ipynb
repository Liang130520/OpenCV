# %% [markdown]
# <a href="https://colab.research.google.com/github/Liang130520/OpenCV/blob/main/OpenCV_classs1020_6_%E5%BD%B1%E5%83%8F%E8%BE%A8%E8%AD%98%E8%A8%93%E7%B7%B4(%E6%9C%AA%E5%AE%8C%E6%88%90).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip classifier_training_colab.zip
# Out:
# Archive:  classifier_training_colab.zip
# warning [classifier_training_colab.zip]:  63963136 extra bytes at beginning or within zipfile
#   (attempting to process anyway)
# file #1:  bad zipfile offset (local header sig):  63963136
#   (attempting to re-compensate)
#    creating: classifier_training_colab/
# error: invalid zip file with overlapped components (possible zip bomb)

# %%
# !python classifier_training_colab/training.py

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import IPython.display as dp
import pytesseract as pt
from pyzbar import pyzbar

m1 = cv2.imread("classifier_training_colab/Data/Image.jpg",-1)
# w =2000
# h = int((m1).shape[1] / (m1.shape[0]/w)) # 設 h 為高, w 為寬, 依同長寬比計算, h * 圖長 = w * 圖高
# # 須注意: 除法會有浮點數, 需轉換為整數, 任意方式皆可
# m1_resize = cv2.resize(m1, (w, h)) # 以(寬, 高)進行縮小放大
# cv2_imshow(m1_resize)

p1 = cv2.CascadeClassifier("classifier_training_colab/xml/cascade.xml")
data = p1.detectMultiScale(m1,minNeighbors=0,minSize=(3,3))
for x, y , w, h in data:
  cv2.rectangle(m1, (x,y), (x+w, y+h), (0, 0, 255), 2)
cv2_imshow(m1)
# Out:
# <PIL.Image.Image image mode=RGB size=800x450 at 0x7F0C9849E290>
